# %% [markdown]
# # Подготовка окружения и скачивание данных

# %%
# Установка необходимых библиотек
# !pip install -q opendatasets lmdb fire natsort

import os
import opendatasets as od
# Скачиваем данные
od.download("https://www.kaggle.com/datasets/ziiiegen/synthetic-ocr-textrecognitiondatagenerator")

#Клонируем FORK репозиторий ClovaAI
# !git clone https://github.com/ziiiegen/deep-text-recognition-benchmark.git
import sys
sys.path.append('/content/deep-text-recognition-benchmark')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.1/333.1 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 5.4 MB/s eta 0:00:00
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: ziiiegen
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/ziiiegen/synthetic-ocr-textrecognitiondatagenerator
# Downloading synthetic-ocr-textrecognitiondatagenerator.zip to ./synthetic-ocr-textrecognitiondatagenerator
# 100%|██████████| 52.3M/52.3M [00:01<00:00, 28.4MB/s]
# Cloning into 'deep-text-recognition-benchmark'...
# remote: Enumerating objects: 545, done.
# remote: Counting objects: 100% (271/271), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 545 (delta 239), reused 234 (delta 218), pack-reused 274 (from 1)
# Receiving objects: 100% (545/545), 3.07 MiB | 31.41 MiB/s, done.
# Resolving deltas: 100% (339/339), done.

# %% [markdown]
# # Подготовка LMDB датасетов (Train / Val)

# %%
import os
import shutil
import lmdb
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split

TRAIN_CSV = "/content/synthetic-ocr-textrecognitiondatagenerator/labels.csv"
TRAIN_IMG_DIR = "/content/synthetic-ocr-textrecognitiondatagenerator/data"

LMDB_TRAIN = "/content/data_lmdb/train"
LMDB_VAL = "/content/data_lmdb/val"

SEED = 42

# очищаем старые базы
for path in [LMDB_TRAIN, LMDB_VAL]:
    if os.path.exists(path):
        shutil.rmtree(path)
    os.makedirs(path, exist_ok=True)

df = pd.read_csv(TRAIN_CSV)
df = df.dropna(subset=["Filename", "Price"]).copy()

# приводим labels к строке из цифр
df["Price"] = df["Price"].astype(str).str.strip()
df["Price"] = df["Price"].str.replace(r"\.0$", "", regex=True)

# оставляем только валидные цифровые метки
df = df[df["Price"].str.fullmatch(r"\d+")].copy()

print("Total valid samples:", len(df))
print(df["Price"].head(10).tolist())

train_df, val_df = train_test_split(df, test_size=0.10, random_state=SEED)

def write_lmdb(df, img_dir, lmdb_path):
    env = lmdb.open(lmdb_path, map_size=1099511627776)
    cnt = 1

    with env.begin(write=True) as txn:
        for _, row in tqdm(df.iterrows(), total=len(df), desc=f"Writing to {lmdb_path}"):
            img_path = os.path.join(img_dir, row["Filename"])

            if not os.path.exists(img_path):
                continue

            try:
                with open(img_path, "rb") as f:
                    imageBin = f.read()
            except:
                continue

            img = cv2.imdecode(np.frombuffer(imageBin, dtype=np.uint8), cv2.IMREAD_GRAYSCALE)
            if img is None:
                continue

            label = str(row["Price"]).strip()

            if not label.isdigit():
                continue

            imageKey = f"image-{cnt:09d}".encode()
            labelKey = f"label-{cnt:09d}".encode()

            txn.put(imageKey, imageBin)
            txn.put(labelKey, label.encode("utf-8"))
            cnt += 1

        txn.put(b"num-samples", str(cnt - 1).encode())

    env.close()

write_lmdb(train_df, TRAIN_IMG_DIR, LMDB_TRAIN)
write_lmdb(val_df, TRAIN_IMG_DIR, LMDB_VAL)
# Out:
# Total valid samples: 50000
# ['814', '27', '85', '50', '28', '270', '810', '940', '49', '19']
# Writing to /content/data_lmdb/train: 100%|██████████| 45000/45000 [00:07<00:00, 5935.62it/s]
# Writing to /content/data_lmdb/val: 100%|██████████| 5000/5000 [00:00<00:00, 7015.28it/s]

# %% [markdown]
# # Обучение модели (Тренировка)

# %%
# !cd /content/deep-text-recognition-benchmark && python -u train.py \
--train_data /content/data_lmdb/train \
--valid_data /content/data_lmdb/val \
--manualSeed 42 \
--select_data "/" \
--batch_ratio 1.0 \
--num_fiducial 4 \
--Transformation TPS \
--FeatureExtraction ResNet \
--SequenceModeling BiLSTM \
--Prediction CTC \
--character "0123456789" \
--batch_max_length 6 \
--imgH 96 \
--imgW 110 \
--hidden_size 256 \
--PAD \
--batch_size 64 \
--workers 2 \
--adamW \
--lr 0.0001 \
--num_iter 10000 \
--valInterval 200 \
--exp_name "sint_10000"
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: /content/data_lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1.0']
# --------------------------------------------------------------------------------
# dataset_root:    /content/data_lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 45000
# num total samples of /: 45000 x 1.0 (total_data_usage_ratio) = 45000
# num samples of / per batch: 64 x 1.0 (batch_ratio) = 64
# --------------------------------------------------------------------------------
# Total_batch_size: 64 = 64
# --------------------------------------------------------------------------------
# dataset_root:    /content/data_lmdb/val	 dataset: /
# sub-directory:	/.	 num samples: 5000
# --------------------------------------------------------------------------------
# model input parameters 96 110 4 1 512 256 11 6 TPS ResNet BiLSTM CTC
# Skip Transformation.LocalizationNetwork.localization_fc2.weight as it is already initialized
# Skip Transformation.LocalizationNetwork.localization_fc2.bias as it is already initialized
# Model:
# DataParallel(
#   (module): Model(
#     (Transformation): TPS_SpatialTransformerNetwork(
#       (LocalizationNetwork): LocalizationNetwork(
#         (conv): Sequential(
#           (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): ReLU(inplace=True)
#           (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (10): ReLU(inplace=True)
#           (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (13): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (14): ReLU(inplace=True)
#           (15): AdaptiveAvgPool2d(output_size=1)
#         )
#         (localization_fc1): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): ReLU(inplace=True)
#         )
#         (localization_fc2): Linear(in_features=256, out_features=8, bias=True)
#       )
#       (GridGenerator): GridGenerator()
#     )
#     (FeatureExtraction): ResNet_FeatureExtractor(
#       (ConvNet): ResNet(
#         (conv0_1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn0_1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv0_2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn0_2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer1): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer2): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (maxpool3): MaxPool2d(kernel_size=2, stride=(2, 1), padding=(0, 1), dilation=1, ceil_mode=False)
#         (layer3): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (2): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (3): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (4): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (layer4): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (2): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv4_1): Conv2d(512, 512, kernel_size=(2, 2), stride=(2, 1), padding=(0, 1), bias=False)
#         (bn4_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv4_2): Conv2d(512, 512, kernel_size=(2, 2), stride=(1, 1), bias=False)
#         (bn4_2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(512, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=11, bias=True)
#   )
# )
# Trainable params num :  48843187
# Optimizer:
# AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.0001
# )
# ------------ Options -------------
# exp_name: price_sint_10000_len6_lr0001
# train_data: /content/data_lmdb/train
# valid_data: /content/data_lmdb/val
# manualSeed: 42
# workers: 2
# batch_size: 64
# num_iter: 10000
# valInterval: 200
# saved_model:
# saved_model_iter: -1
# FT: False
# adamW: True
# lr: 0.0001
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# baiduCTC: False
# select_data: ['/']
# batch_ratio: ['1.0']
# total_data_usage_ratio: 1.0
# batch_max_length: 6
# imgH: 96
# imgW: 110
# rgb: False
# character: 0123456789
# sensitive: False
# PAD: True
# data_filtering_off: False
# Transformation: TPS
# FeatureExtraction: ResNet
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 4
# input_channel: 1
# output_channel: 512
# hidden_size: 256
# num_gpu: 1
# num_class: 11
# ---------------------------------------
#
# Train model:   0% 0/200 [00:00<?, ?it/s][1/10000] Train loss: 23.90345, Valid loss: 23.79324, Elapsed_time: 20.32169, current_LR: 0.0001000
# Current_accuracy : 0.140, Current_norm_ED  : 0.12
# Best_accuracy    : 0.140, Best_norm_ED     : 0.12
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 99                        | 390                       | 0.0000	False
# 24                        | 30                        | 0.0000	False
# 98                        | 3930                      | 0.0000	False
# 35                        | 30                        | 0.0000	False
# 11                        | 93893070                  | 0.0000	False
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [200/10000] Train loss: 2.23622, Valid loss: 0.74686, Elapsed_time: 244.47563, current_LR: 0.0000999
# Current_accuracy : 43.160, Current_norm_ED  : 0.75
# Best_accuracy    : 43.160, Best_norm_ED     : 0.75
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 80                        | 80                        | 0.6496	True
# 480                       | 40                        | 0.2923	False
# 32                        | 32                        | 0.2965	True
# 417                       | 47                        | 0.4026	False
# 18                        | 18                        | 0.6888	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [400/10000] Train loss: 0.69040, Valid loss: 0.21567, Elapsed_time: 447.79312, current_LR: 0.0000996
# Current_accuracy : 89.600, Current_norm_ED  : 0.95
# Best_accuracy    : 89.600, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 125                       | 125                       | 0.6461	True
# 74                        | 14                        | 0.7787	False
# 273                       | 273                       | 0.3644	True
# 57                        | 57                        | 0.8618	True
# 34                        | 34                        | 0.9133	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [600/10000] Train loss: 0.43958, Valid loss: 0.14450, Elapsed_time: 653.15493, current_LR: 0.0000991
# Current_accuracy : 91.580, Current_norm_ED  : 0.96
# Best_accuracy    : 91.580, Best_norm_ED     : 0.96
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 25                        | 25                        | 0.9299	True
# 935                       | 95                        | 0.4216	False
# 549                       | 549                       | 0.9114	True
# 206                       | 206                       | 0.8350	True
# 367                       | 367                       | 0.9098	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [800/10000] Train loss: 0.34987, Valid loss: 0.08334, Elapsed_time: 861.63070, current_LR: 0.0000984
# Current_accuracy : 95.840, Current_norm_ED  : 0.98
# Best_accuracy    : 95.840, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 71                        | 71                        | 0.5971	True
# 269                       | 269                       | 0.5980	True
# 376                       | 376                       | 0.5975	True
# 863                       | 863                       | 0.7267	True
# 541                       | 541                       | 0.9314	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [1000/10000] Train loss: 0.29231, Valid loss: 0.07606, Elapsed_time: 1067.32134, current_LR: 0.0000976
# Current_accuracy : 95.240, Current_norm_ED  : 0.98
# Best_accuracy    : 95.840, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 828                       | 828                       | 0.9675	True
# 31                        | 31                        | 0.9831	True
# 150                       | 150                       | 0.7049	True
# 92                        | 92                        | 0.9895	True
# 45                        | 45                        | 0.9884	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [1200/10000] Train loss: 0.27197, Valid loss: 0.05812, Elapsed_time: 1265.70350, current_LR: 0.0000965
# Current_accuracy : 96.380, Current_norm_ED  : 0.98
# Best_accuracy    : 96.380, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 24                        | 24                        | 0.9912	True
# 51                        | 51                        | 0.9751	True
# 59                        | 59                        | 0.9812	True
# 37                        | 37                        | 0.9799	True
# 503                       | 503                       | 0.9345	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [1400/10000] Train loss: 0.25362, Valid loss: 0.08574, Elapsed_time: 1471.49491, current_LR: 0.0000953
# Current_accuracy : 94.580, Current_norm_ED  : 0.98
# Best_accuracy    : 96.380, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 38                        | 38                        | 0.9829	True
# 642                       | 642                       | 0.9731	True
# 27                        | 27                        | 0.9330	True
# 77                        | 77                        | 0.9794	True
# 578                       | 578                       | 0.8526	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [1600/10000] Train loss: 0.20931, Valid loss: 0.05006, Elapsed_time: 1669.07026, current_LR: 0.0000939
# Current_accuracy : 96.840, Current_norm_ED  : 0.99
# Best_accuracy    : 96.840, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 80                        | 80                        | 0.9942	True
# 22                        | 22                        | 0.9946	True
# 760                       | 760                       | 0.8192	True
# 61                        | 61                        | 0.9290	True
# 201                       | 201                       | 0.5750	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [1800/10000] Train loss: 0.20806, Valid loss: 0.04984, Elapsed_time: 1870.67284, current_LR: 0.0000923
# Current_accuracy : 96.700, Current_norm_ED  : 0.99
# Best_accuracy    : 96.840, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 82                        | 82                        | 0.9939	True
# 55                        | 55                        | 0.9789	True
# 15                        | 15                        | 0.9948	True
# 100                       | 100                       | 0.9877	True
# 27                        | 27                        | 0.9871	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [2000/10000] Train loss: 0.21207, Valid loss: 0.03987, Elapsed_time: 2071.94610, current_LR: 0.0000905
# Current_accuracy : 97.460, Current_norm_ED  : 0.99
# Best_accuracy    : 97.460, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 420                       | 420                       | 0.6556	True
# 7405                      | 7405                      | 0.9170	True
# 370                       | 370                       | 0.9755	True
# 9                         | 9                         | 0.9905	True
# 96                        | 96                        | 0.9969	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [2200/10000] Train loss: 0.19281, Valid loss: 0.03637, Elapsed_time: 2270.61757, current_LR: 0.0000886
# Current_accuracy : 97.640, Current_norm_ED  : 0.99
# Best_accuracy    : 97.640, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 731                       | 731                       | 0.9597	True
# 31                        | 31                        | 0.9875	True
# 66                        | 66                        | 0.9770	True
# 304                       | 304                       | 0.9831	True
# 712                       | 712                       | 0.7934	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [2400/10000] Train loss: 0.18102, Valid loss: 0.03712, Elapsed_time: 2476.01198, current_LR: 0.0000866
# Current_accuracy : 97.320, Current_norm_ED  : 0.99
# Best_accuracy    : 97.640, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 224                       | 224                       | 0.9804	True
# 417                       | 417                       | 0.8497	True
# 100                       | 100                       | 0.8978	True
# 83                        | 83                        | 0.9905	True
# 641                       | 641                       | 0.9689	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [2600/10000] Train loss: 0.17396, Valid loss: 0.02554, Elapsed_time: 2673.74053, current_LR: 0.0000844
# Current_accuracy : 98.300, Current_norm_ED  : 0.99
# Best_accuracy    : 98.300, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 13                        | 13                        | 0.9601	True
# 60                        | 60                        | 0.9732	True
# 145                       | 145                       | 0.5018	True
# 18                        | 18                        | 0.9885	True
# 300                       | 300                       | 0.9476	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [2800/10000] Train loss: 0.17313, Valid loss: 0.03046, Elapsed_time: 2872.91026, current_LR: 0.0000821
# Current_accuracy : 98.020, Current_norm_ED  : 0.99
# Best_accuracy    : 98.300, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 38                        | 38                        | 0.9935	True
# 3                         | 3                         | 0.9910	True
# 41                        | 41                        | 0.9937	True
# 22                        | 22                        | 0.9977	True
# 30                        | 30                        | 0.9861	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [3000/10000] Train loss: 0.16346, Valid loss: 0.02099, Elapsed_time: 3071.22403, current_LR: 0.0000796
# Current_accuracy : 98.460, Current_norm_ED  : 0.99
# Best_accuracy    : 98.460, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 36                        | 36                        | 0.9911	True
# 612                       | 612                       | 0.9849	True
# 14                        | 14                        | 0.9826	True
# 529                       | 529                       | 0.9916	True
# 29                        | 29                        | 0.9923	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [3200/10000] Train loss: 0.14150, Valid loss: 0.03108, Elapsed_time: 3271.30272, current_LR: 0.0000770
# Current_accuracy : 97.920, Current_norm_ED  : 0.99
# Best_accuracy    : 98.460, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 783                       | 783                       | 0.7047	True
# 84                        | 84                        | 0.9951	True
# 737                       | 737                       | 0.5950	True
# 31                        | 31                        | 0.9714	True
# 95                        | 95                        | 0.9961	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [3400/10000] Train loss: 0.15721, Valid loss: 0.02358, Elapsed_time: 3469.18465, current_LR: 0.0000743
# Current_accuracy : 98.660, Current_norm_ED  : 0.99
# Best_accuracy    : 98.660, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 220                       | 220                       | 0.6199	True
# 942                       | 942                       | 0.9936	True
# 84                        | 84                        | 0.9972	True
# 207                       | 207                       | 0.9014	True
# 68                        | 68                        | 0.9973	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [3600/10000] Train loss: 0.14182, Valid loss: 0.01968, Elapsed_time: 3668.16179, current_LR: 0.0000716
# Current_accuracy : 98.760, Current_norm_ED  : 0.99
# Best_accuracy    : 98.760, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 183                       | 183                       | 0.9839	True
# 476                       | 476                       | 0.9916	True
# 98                        | 98                        | 0.9966	True
# 66                        | 66                        | 0.9982	True
# 61                        | 61                        | 0.9975	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [3800/10000] Train loss: 0.13118, Valid loss: 0.02619, Elapsed_time: 3868.02665, current_LR: 0.0000687
# Current_accuracy : 98.260, Current_norm_ED  : 0.99
# Best_accuracy    : 98.760, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 58                        | 58                        | 0.9952	True
# 87                        | 87                        | 0.9978	True
# 92                        | 92                        | 0.9964	True
# 85                        | 85                        | 0.9972	True
# 452                       | 452                       | 0.9739	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [4000/10000] Train loss: 0.13571, Valid loss: 0.02709, Elapsed_time: 4065.74631, current_LR: 0.0000658
# Current_accuracy : 98.280, Current_norm_ED  : 0.99
# Best_accuracy    : 98.760, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 28                        | 28                        | 0.9965	True
# 4                         | 4                         | 0.9934	True
# 41                        | 41                        | 0.9958	True
# 114                       | 114                       | 0.9091	True
# 42                        | 42                        | 0.9958	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [4200/10000] Train loss: 0.13613, Valid loss: 0.02020, Elapsed_time: 4264.33663, current_LR: 0.0000628
# Current_accuracy : 98.680, Current_norm_ED  : 0.99
# Best_accuracy    : 98.760, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 560                       | 560                       | 0.9798	True
# 115                       | 115                       | 0.9914	True
# 48                        | 48                        | 0.9426	True
# 213                       | 213                       | 0.8650	True
# 958                       | 958                       | 0.9933	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [4400/10000] Train loss: 0.13169, Valid loss: 0.01729, Elapsed_time: 4461.99291, current_LR: 0.0000598
# Current_accuracy : 98.840, Current_norm_ED  : 0.99
# Best_accuracy    : 98.840, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 29                        | 29                        | 0.9932	True
# 402                       | 402                       | 0.9960	True
# 98                        | 98                        | 0.9952	True
# 864                       | 864                       | 0.9177	True
# 4372                      | 4372                      | 0.8407	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [4600/10000] Train loss: 0.11400, Valid loss: 0.01567, Elapsed_time: 4660.72328, current_LR: 0.0000567
# Current_accuracy : 99.040, Current_norm_ED  : 1.00
# Best_accuracy    : 99.040, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 85                        | 85                        | 0.9969	True
# 494                       | 494                       | 0.9368	True
# 435                       | 435                       | 0.9936	True
# 81                        | 81                        | 0.9952	True
# 76                        | 76                        | 0.9893	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [4800/10000] Train loss: 0.12476, Valid loss: 0.01430, Elapsed_time: 4860.03920, current_LR: 0.0000536
# Current_accuracy : 99.080, Current_norm_ED  : 1.00
# Best_accuracy    : 99.080, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 491                       | 491                       | 0.9898	True
# 673                       | 673                       | 0.9979	True
# 199                       | 199                       | 0.9849	True
# 591                       | 591                       | 0.9954	True
# 57                        | 57                        | 0.9977	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [5000/10000] Train loss: 0.12083, Valid loss: 0.01831, Elapsed_time: 5061.53343, current_LR: 0.0000505
# Current_accuracy : 98.760, Current_norm_ED  : 0.99
# Best_accuracy    : 99.080, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 24                        | 24                        | 0.9974	True
# 164                       | 164                       | 0.9548	True
# 93                        | 93                        | 0.9945	True
# 55                        | 55                        | 0.9967	True
# 43                        | 43                        | 0.9985	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [5200/10000] Train loss: 0.10506, Valid loss: 0.01615, Elapsed_time: 5259.30054, current_LR: 0.0000474
# Current_accuracy : 98.820, Current_norm_ED  : 0.99
# Best_accuracy    : 99.080, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 217                       | 217                       | 0.9938	True
# 918                       | 918                       | 0.5508	True
# 227                       | 227                       | 0.9676	True
# 547                       | 547                       | 0.9846	True
# 86                        | 86                        | 0.9978	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [5400/10000] Train loss: 0.11267, Valid loss: 0.01195, Elapsed_time: 5457.24373, current_LR: 0.0000443
# Current_accuracy : 99.100, Current_norm_ED  : 1.00
# Best_accuracy    : 99.100, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 344                       | 344                       | 0.9875	True
# 52                        | 52                        | 0.9982	True
# 43                        | 43                        | 0.9958	True
# 14                        | 14                        | 0.9757	True
# 487                       | 487                       | 0.8999	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [5600/10000] Train loss: 0.11221, Valid loss: 0.01372, Elapsed_time: 5662.62288, current_LR: 0.0000412
# Current_accuracy : 98.920, Current_norm_ED  : 1.00
# Best_accuracy    : 99.100, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 72                        | 72                        | 0.9899	True
# 43                        | 43                        | 0.9984	True
# 6                         | 6                         | 0.9986	True
# 13                        | 13                        | 0.9955	True
# 65                        | 65                        | 0.9985	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [5800/10000] Train loss: 0.09829, Valid loss: 0.01013, Elapsed_time: 5860.82352, current_LR: 0.0000382
# Current_accuracy : 99.220, Current_norm_ED  : 1.00
# Best_accuracy    : 99.220, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 196                       | 196                       | 0.9847	True
# 966                       | 966                       | 0.8722	True
# 776                       | 776                       | 0.9969	True
# 96                        | 96                        | 0.9975	True
# 231                       | 231                       | 0.9977	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [6000/10000] Train loss: 0.09612, Valid loss: 0.01068, Elapsed_time: 6065.75583, current_LR: 0.0000352
# Current_accuracy : 99.220, Current_norm_ED  : 1.00
# Best_accuracy    : 99.220, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 185                       | 185                       | 0.9969	True
# 97                        | 97                        | 0.9961	True
# 87                        | 87                        | 0.9980	True
# 185                       | 185                       | 0.9920	True
# 633                       | 633                       | 0.9914	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [6200/10000] Train loss: 0.10313, Valid loss: 0.01174, Elapsed_time: 6264.05994, current_LR: 0.0000323
# Current_accuracy : 99.240, Current_norm_ED  : 1.00
# Best_accuracy    : 99.240, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 84                        | 84                        | 0.9962	True
# 369                       | 369                       | 0.9949	True
# 80                        | 80                        | 0.9963	True
# 617                       | 617                       | 0.9848	True
# 16                        | 16                        | 0.9891	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [6400/10000] Train loss: 0.09998, Valid loss: 0.01025, Elapsed_time: 6462.18150, current_LR: 0.0000294
# Current_accuracy : 99.200, Current_norm_ED  : 1.00
# Best_accuracy    : 99.240, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9                         | 9                         | 0.9985	True
# 70                        | 70                        | 0.9911	True
# 64                        | 64                        | 0.9975	True
# 522                       | 522                       | 0.7894	True
# 58                        | 58                        | 0.9981	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [6600/10000] Train loss: 0.08381, Valid loss: 0.00872, Elapsed_time: 6661.29388, current_LR: 0.0000267
# Current_accuracy : 99.320, Current_norm_ED  : 1.00
# Best_accuracy    : 99.320, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 491                       | 491                       | 0.9351	True
# 100                       | 100                       | 0.9869	True
# 57                        | 57                        | 0.9983	True
# 876                       | 876                       | 0.7504	True
# 71                        | 71                        | 0.9945	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [6800/10000] Train loss: 0.09373, Valid loss: 0.00925, Elapsed_time: 6864.90839, current_LR: 0.0000240
# Current_accuracy : 99.280, Current_norm_ED  : 1.00
# Best_accuracy    : 99.320, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 34                        | 34                        | 0.9987	True
# 685                       | 685                       | 0.9962	True
# 37                        | 37                        | 0.9984	True
# 33                        | 33                        | 0.9985	True
# 10                        | 10                        | 0.9984	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [7000/10000] Train loss: 0.09161, Valid loss: 0.00905, Elapsed_time: 7063.19892, current_LR: 0.0000214
# Current_accuracy : 99.360, Current_norm_ED  : 1.00
# Best_accuracy    : 99.360, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 44                        | 44                        | 0.9968	True
# 39                        | 39                        | 0.9983	True
# 38                        | 38                        | 0.9981	True
# 76                        | 76                        | 0.9992	True
# 2785                      | 2785                      | 0.9942	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [7200/10000] Train loss: 0.07929, Valid loss: 0.00902, Elapsed_time: 7284.76796, current_LR: 0.0000189
# Current_accuracy : 99.320, Current_norm_ED  : 1.00
# Best_accuracy    : 99.360, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 82                        | 82                        | 0.9992	True
# 485                       | 485                       | 0.9960	True
# 39                        | 39                        | 0.9984	True
# 633                       | 633                       | 0.9970	True
# 98                        | 98                        | 0.9968	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [7400/10000] Train loss: 0.08044, Valid loss: 0.01052, Elapsed_time: 7482.92358, current_LR: 0.0000166
# Current_accuracy : 99.320, Current_norm_ED  : 1.00
# Best_accuracy    : 99.360, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5                         | 5                         | 0.9988	True
# 11                        | 11                        | 0.9960	True
# 62                        | 62                        | 0.9988	True
# 34                        | 34                        | 0.9982	True
# 38                        | 3                         | 0.8836	False
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [7600/10000] Train loss: 0.08448, Valid loss: 0.00720, Elapsed_time: 7681.67917, current_LR: 0.0000144
# Current_accuracy : 99.460, Current_norm_ED  : 1.00
# Best_accuracy    : 99.460, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 64                        | 64                        | 0.9989	True
# 555                       | 555                       | 0.9986	True
# 47                        | 47                        | 0.9990	True
# 57                        | 57                        | 0.9985	True
# 357                       | 357                       | 0.9895	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [7800/10000] Train loss: 0.08555, Valid loss: 0.00909, Elapsed_time: 7880.92642, current_LR: 0.0000124
# Current_accuracy : 99.300, Current_norm_ED  : 1.00
# Best_accuracy    : 99.460, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 80                        | 80                        | 0.9990	True
# 78                        | 78                        | 0.9968	True
# 99                        | 99                        | 0.9976	True
# 125                       | 125                       | 0.9969	True
# 64                        | 64                        | 0.9981	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [8000/10000] Train loss: 0.07668, Valid loss: 0.00756, Elapsed_time: 8079.58193, current_LR: 0.0000105
# Current_accuracy : 99.460, Current_norm_ED  : 1.00
# Best_accuracy    : 99.460, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 74                        | 74                        | 0.9988	True
# 402                       | 402                       | 0.9983	True
# 83                        | 83                        | 0.9980	True
# 569                       | 569                       | 0.9048	True
# 49                        | 49                        | 0.9987	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [8200/10000] Train loss: 0.07409, Valid loss: 0.01029, Elapsed_time: 8278.74512, current_LR: 0.0000087
# Current_accuracy : 99.460, Current_norm_ED  : 1.00
# Best_accuracy    : 99.460, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 28                        | 28                        | 0.9997	True
# 137                       | 937                       | 0.1324	False
# 27                        | 27                        | 0.9978	True
# 42                        | 42                        | 0.9987	True
# 9455                      | 9455                      | 0.9921	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [8400/10000] Train loss: 0.08592, Valid loss: 0.00760, Elapsed_time: 8483.48177, current_LR: 0.0000071
# Current_accuracy : 99.420, Current_norm_ED  : 1.00
# Best_accuracy    : 99.460, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 91                        | 91                        | 0.9988	True
# 914                       | 914                       | 0.9112	True
# 887                       | 887                       | 0.9985	True
# 150                       | 150                       | 0.7240	True
# 22                        | 22                        | 0.9991	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [8600/10000] Train loss: 0.07513, Valid loss: 0.00722, Elapsed_time: 8681.55611, current_LR: 0.0000057
# Current_accuracy : 99.520, Current_norm_ED  : 1.00
# Best_accuracy    : 99.520, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 78                        | 78                        | 0.9984	True
# 80                        | 80                        | 0.9993	True
# 51                        | 51                        | 0.9982	True
# 187                       | 187                       | 0.9977	True
# 90                        | 90                        | 0.9988	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [8800/10000] Train loss: 0.06626, Valid loss: 0.00686, Elapsed_time: 8881.39088, current_LR: 0.0000045
# Current_accuracy : 99.480, Current_norm_ED  : 1.00
# Best_accuracy    : 99.520, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 21                        | 21                        | 0.9992	True
# 75                        | 75                        | 0.9983	True
# 168                       | 168                       | 0.9982	True
# 993                       | 993                       | 0.9966	True
# 30                        | 30                        | 0.9985	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [9000/10000] Train loss: 0.07388, Valid loss: 0.00718, Elapsed_time: 9079.52808, current_LR: 0.0000034
# Current_accuracy : 99.480, Current_norm_ED  : 1.00
# Best_accuracy    : 99.520, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 237                       | 237                       | 0.7849	True
# 159                       | 159                       | 0.8657	True
# 844                       | 844                       | 0.9797	True
# 7516                      | 7516                      | 0.7194	True
# 99                        | 99                        | 0.9958	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [9200/10000] Train loss: 0.07589, Valid loss: 0.00693, Elapsed_time: 9276.94087, current_LR: 0.0000026
# Current_accuracy : 99.520, Current_norm_ED  : 1.00
# Best_accuracy    : 99.520, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 212                       | 212                       | 0.9951	True
# 465                       | 465                       | 0.9568	True
# 99                        | 99                        | 0.9989	True
# 27                        | 27                        | 0.9995	True
# 837                       | 837                       | 0.9958	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [9400/10000] Train loss: 0.06684, Valid loss: 0.00699, Elapsed_time: 9476.10987, current_LR: 0.0000019
# Current_accuracy : 99.500, Current_norm_ED  : 1.00
# Best_accuracy    : 99.520, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 344                       | 344                       | 0.8220	True
# 66                        | 66                        | 0.9996	True
# 700                       | 700                       | 0.9984	True
# 58                        | 58                        | 0.9994	True
# 272                       | 272                       | 0.7329	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [9600/10000] Train loss: 0.06742, Valid loss: 0.00712, Elapsed_time: 9674.44611, current_LR: 0.0000014
# Current_accuracy : 99.520, Current_norm_ED  : 1.00
# Best_accuracy    : 99.520, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 920                       | 920                       | 0.9979	True
# 619                       | 619                       | 0.9989	True
# 57                        | 57                        | 0.9989	True
# 52                        | 52                        | 0.9992	True
# 14                        | 14                        | 0.9969	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [9800/10000] Train loss: 0.07890, Valid loss: 0.00712, Elapsed_time: 9872.80889, current_LR: 0.0000011
# Current_accuracy : 99.520, Current_norm_ED  : 1.00
# Best_accuracy    : 99.520, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 74                        | 74                        | 0.9982	True
# 40                        | 40                        | 0.9978	True
# 48                        | 48                        | 0.9964	True
# 10                        | 10                        | 0.9988	True
# 71                        | 71                        | 0.9992	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [10000/10000] Train loss: 0.06808, Valid loss: 0.00737, Elapsed_time: 10070.14423, current_LR: 0.0000010
# Current_accuracy : 99.440, Current_norm_ED  : 1.00
# Best_accuracy    : 99.520, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 345                       | 345                       | 0.6624	True
# 688                       | 688                       | 0.8680	True
# 990                       | 990                       | 0.9981	True
# 48                        | 48                        | 0.9985	True
# 916                       | 916                       | 0.6473	True
# --------------------------------------------------------------------------------
# end the training
# Train model:   0% 0/200 [00:28<?, ?it/s]
