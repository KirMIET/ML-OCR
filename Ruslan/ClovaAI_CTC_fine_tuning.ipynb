# %% [markdown]
# # Подготовка окружения и скачивание данных

# %%
# Установка необходимых библиотек
# !pip install -q opendatasets lmdb fire natsort

import os
import opendatasets as od
# Скачиваем данные
od.download("https://www.kaggle.com/datasets/ziiiegen/price-ocr-data")

#Клонируем FORK репозиторий ClovaAI
# !git clone https://github.com/ziiiegen/deep-text-recognition-benchmark.git
import sys
sys.path.append('/content/deep-text-recognition-benchmark')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.1/333.1 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 7.2 MB/s eta 0:00:00
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: ziiiegen
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/ziiiegen/price-ocr-data
# Downloading price-ocr-data.zip to ./price-ocr-data
# 100%|██████████| 23.5M/23.5M [00:02<00:00, 9.23MB/s]
# Cloning into 'deep-text-recognition-benchmark'...
# remote: Enumerating objects: 545, done.
# remote: Counting objects: 100% (271/271), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 545 (delta 239), reused 234 (delta 218), pack-reused 274 (from 1)
# Receiving objects: 100% (545/545), 3.07 MiB | 35.29 MiB/s, done.
# Resolving deltas: 100% (339/339), done.

# %% [markdown]
# # Подготовка LMDB датасетов (Train / Val)

# %%
import os
import shutil
import lmdb
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split

TRAIN_CSV = "/content/price-ocr-data/OCR_DATA/train.csv"
TRAIN_IMG_DIR = "/content/price-ocr-data/OCR_DATA/train/train"

LMDB_TRAIN = "/content/data_lmdb/train"
LMDB_VAL = "/content/data_lmdb/val"

SEED = 40

# очищаем старые базы
for path in [LMDB_TRAIN, LMDB_VAL]:
    if os.path.exists(path):
        shutil.rmtree(path)
    os.makedirs(path, exist_ok=True)

df = pd.read_csv(TRAIN_CSV)
df = df.dropna(subset=["Filename", "Price"]).copy()

# приводим labels к строке из цифр
df["Price"] = df["Price"].astype(str).str.strip()
df["Price"] = df["Price"].str.replace(r"\.0$", "", regex=True)

# оставляем только валидные цифровые метки
df = df[df["Price"].str.fullmatch(r"\d+")].copy()

print("Total valid samples:", len(df))
print(df["Price"].head(10).tolist())

train_df, val_df = train_test_split(df, test_size=0.10, random_state=SEED)

def write_lmdb(df, img_dir, lmdb_path):
    env = lmdb.open(lmdb_path, map_size=1099511627776)
    cnt = 1

    with env.begin(write=True) as txn:
        for _, row in tqdm(df.iterrows(), total=len(df), desc=f"Writing to {lmdb_path}"):
            img_path = os.path.join(img_dir, row["Filename"])

            if not os.path.exists(img_path):
                continue

            try:
                with open(img_path, "rb") as f:
                    imageBin = f.read()
            except:
                continue

            img = cv2.imdecode(np.frombuffer(imageBin, dtype=np.uint8), cv2.IMREAD_GRAYSCALE)
            if img is None:
                continue

            label = str(row["Price"]).strip()

            if not label.isdigit():
                continue

            imageKey = f"image-{cnt:09d}".encode()
            labelKey = f"label-{cnt:09d}".encode()

            txn.put(imageKey, imageBin)
            txn.put(labelKey, label.encode("utf-8"))
            cnt += 1

        txn.put(b"num-samples", str(cnt - 1).encode())

    env.close()

write_lmdb(train_df, TRAIN_IMG_DIR, LMDB_TRAIN)
write_lmdb(val_df, TRAIN_IMG_DIR, LMDB_VAL)
# Out:
# Total valid samples: 18136
# ['66', '35', '57', '57', '25', '189', '46', '34', '1139', '34']
# Writing to /content/data_lmdb/train: 100%|██████████| 16322/16322 [00:03<00:00, 5199.01it/s]
# Writing to /content/data_lmdb/val: 100%|██████████| 1814/1814 [00:00<00:00, 7429.49it/s]

# %% [markdown]
# # Обучение модели (Тренировка)

# %%
# !cd /content/deep-text-recognition-benchmark && python -u train.py \
--train_data /content/data_lmdb/train \
--valid_data /content/data_lmdb/val \
--manualSeed 42 \
--select_data "/" \
--batch_ratio 1.0 \
--num_fiducial 4 \
--Transformation TPS \
--FeatureExtraction ResNet \
--SequenceModeling BiLSTM \
--Prediction CTC \
--character "0123456789" \
--batch_max_length 6 \
--imgH 96 \
--imgW 110 \
--hidden_size 256 \
--PAD \
--batch_size 64 \
--workers 2 \
--adamW \
--lr 0.00001 \
--num_iter 5000 \
--valInterval 200 \
--saved_model /content/last.pth\
--saved_model_iter 0 \
--exp_name "fine_tuning_ctc"
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: /content/data_lmdb/train
# opt.select_data: ['/']
# opt.batch_ratio: ['1.0']
# --------------------------------------------------------------------------------
# dataset_root:    /content/data_lmdb/train	 dataset: /
# sub-directory:	/.	 num samples: 16322
# num total samples of /: 16322 x 1.0 (total_data_usage_ratio) = 16322
# num samples of / per batch: 64 x 1.0 (batch_ratio) = 64
# --------------------------------------------------------------------------------
# Total_batch_size: 64 = 64
# --------------------------------------------------------------------------------
# dataset_root:    /content/data_lmdb/val	 dataset: /
# sub-directory:	/.	 num samples: 1814
# --------------------------------------------------------------------------------
# model input parameters 96 110 4 1 512 256 11 6 TPS ResNet BiLSTM CTC
# Skip Transformation.LocalizationNetwork.localization_fc2.weight as it is already initialized
# Skip Transformation.LocalizationNetwork.localization_fc2.bias as it is already initialized
# loading pretrained model from /content/last.pth
# Model:
# DataParallel(
#   (module): Model(
#     (Transformation): TPS_SpatialTransformerNetwork(
#       (LocalizationNetwork): LocalizationNetwork(
#         (conv): Sequential(
#           (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): ReLU(inplace=True)
#           (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (10): ReLU(inplace=True)
#           (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (13): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (14): ReLU(inplace=True)
#           (15): AdaptiveAvgPool2d(output_size=1)
#         )
#         (localization_fc1): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): ReLU(inplace=True)
#         )
#         (localization_fc2): Linear(in_features=256, out_features=8, bias=True)
#       )
#       (GridGenerator): GridGenerator()
#     )
#     (FeatureExtraction): ResNet_FeatureExtractor(
#       (ConvNet): ResNet(
#         (conv0_1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn0_1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv0_2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn0_2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer1): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer2): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (maxpool3): MaxPool2d(kernel_size=2, stride=(2, 1), padding=(0, 1), dilation=1, ceil_mode=False)
#         (layer3): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (2): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (3): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (4): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (layer4): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (2): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv4_1): Conv2d(512, 512, kernel_size=(2, 2), stride=(2, 1), padding=(0, 1), bias=False)
#         (bn4_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv4_2): Conv2d(512, 512, kernel_size=(2, 2), stride=(1, 1), bias=False)
#         (bn4_2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(512, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=11, bias=True)
#   )
# )
# Trainable params num :  48843187
# Optimizer:
# AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: True
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0.0001
# )
# ------------ Options -------------
# exp_name: price_tags_ctc_sint
# train_data: /content/data_lmdb/train
# valid_data: /content/data_lmdb/val
# manualSeed: 42
# workers: 2
# batch_size: 64
# num_iter: 5000
# valInterval: 200
# saved_model: /content/last.pth
# saved_model_iter: 0
# FT: False
# adamW: True
# lr: 1e-05
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# baiduCTC: False
# select_data: ['/']
# batch_ratio: ['1.0']
# total_data_usage_ratio: 1.0
# batch_max_length: 6
# imgH: 96
# imgW: 110
# rgb: False
# character: 0123456789
# sensitive: False
# PAD: True
# data_filtering_off: False
# Transformation: TPS
# FeatureExtraction: ResNet
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 4
# input_channel: 1
# output_channel: 512
# hidden_size: 256
# num_gpu: 1
# num_class: 11
# ---------------------------------------
#
# Train model:   0% 0/200 [00:00<?, ?it/s][1/5000] Train loss: 3.29230, Valid loss: 2.34227, Elapsed_time: 22.95882, current_LR: 0.0000100
# Current_accuracy : 26.240, Current_norm_ED  : 0.54
# Best_accuracy    : 26.240, Best_norm_ED     : 0.54
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 39                        | 81                        | 0.0191	False
# 85082                     | 500                       | 0.1629	False
# 169                       | 69                        | 0.9979	False
# 109                       | 109                       | 0.8438	True
# 89                        | 39                        | 0.4003	False
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [200/5000] Train loss: 0.52131, Valid loss: 0.06269, Elapsed_time: 219.40569, current_LR: 0.0000100
# Current_accuracy : 95.204, Current_norm_ED  : 0.98
# Best_accuracy    : 95.204, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 199                       | 199                       | 0.9950	True
# 358                       | 358                       | 0.5397	True
# 72                        | 72                        | 0.9973	True
# 42                        | 42                        | 0.9933	True
# 96                        | 96                        | 0.9973	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [400/5000] Train loss: 0.14001, Valid loss: 0.04187, Elapsed_time: 417.57846, current_LR: 0.0000099
# Current_accuracy : 97.078, Current_norm_ED  : 0.99
# Best_accuracy    : 97.078, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 52                        | 52                        | 0.9549	True
# 71                        | 71                        | 0.9587	True
# 399                       | 399                       | 0.9956	True
# 72                        | 72                        | 0.9963	True
# 16                        | 16                        | 0.9952	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [600/5000] Train loss: 0.11005, Valid loss: 0.03154, Elapsed_time: 615.62285, current_LR: 0.0000097
# Current_accuracy : 97.850, Current_norm_ED  : 0.99
# Best_accuracy    : 97.850, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 89                        | 89                        | 0.9965	True
# 96                        | 96                        | 0.9972	True
# 4322                      | 4322                      | 0.9868	True
# 179                       | 179                       | 0.9828	True
# 32                        | 32                        | 0.9838	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [800/5000] Train loss: 0.09160, Valid loss: 0.02696, Elapsed_time: 811.56587, current_LR: 0.0000094
# Current_accuracy : 98.015, Current_norm_ED  : 0.99
# Best_accuracy    : 98.015, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 89                        | 89                        | 0.9962	True
# 369                       | 369                       | 0.9862	True
# 399                       | 399                       | 0.9862	True
# 469                       | 469                       | 0.5597	True
# 47                        | 47                        | 0.9952	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [1000/5000] Train loss: 0.08525, Valid loss: 0.02618, Elapsed_time: 1010.32946, current_LR: 0.0000091
# Current_accuracy : 98.236, Current_norm_ED  : 0.99
# Best_accuracy    : 98.236, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 219                       | 219                       | 0.9944	True
# 189                       | 189                       | 0.8966	True
# 34                        | 34                        | 0.9942	True
# 114                       | 114                       | 0.7519	True
# 279                       | 279                       | 0.9965	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [1200/5000] Train loss: 0.07629, Valid loss: 0.02360, Elapsed_time: 1206.66618, current_LR: 0.0000088
# Current_accuracy : 98.622, Current_norm_ED  : 0.99
# Best_accuracy    : 98.622, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 89                        | 89                        | 0.9908	True
# 37                        | 37                        | 0.9780	True
# 299                       | 299                       | 0.9902	True
# 179                       | 179                       | 0.9824	True
# 9120                      | 9120                      | 0.8771	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [1400/5000] Train loss: 0.07369, Valid loss: 0.02602, Elapsed_time: 1403.07946, current_LR: 0.0000084
# Current_accuracy : 98.181, Current_norm_ED  : 0.99
# Best_accuracy    : 98.622, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 129                       | 129                       | 0.6246	True
# 0                         | 0                         | 0.6210	True
# 72                        | 72                        | 0.9980	True
# 399                       | 399                       | 0.9965	True
# 96                        | 96                        | 0.9961	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [1600/5000] Train loss: 0.06838, Valid loss: 0.02496, Elapsed_time: 1598.06414, current_LR: 0.0000079
# Current_accuracy : 98.567, Current_norm_ED  : 1.00
# Best_accuracy    : 98.622, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 49                        | 9                         | 0.7456	False
# 96                        | 96                        | 0.9948	True
# 49                        | 49                        | 0.9989	True
# 32                        | 32                        | 0.9915	True
# 86                        | 86                        | 0.9894	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [1800/5000] Train loss: 0.06415, Valid loss: 0.02492, Elapsed_time: 1793.58815, current_LR: 0.0000074
# Current_accuracy : 98.346, Current_norm_ED  : 0.99
# Best_accuracy    : 98.622, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4299                      | 4299                      | 0.9752	True
# 219                       | 219                       | 0.9299	True
# 21                        | 21                        | 0.9700	True
# 89                        | 89                        | 0.9943	True
# 1850                      | 1850                      | 0.5115	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [2000/5000] Train loss: 0.05730, Valid loss: 0.02610, Elapsed_time: 1989.24305, current_LR: 0.0000069
# Current_accuracy : 98.677, Current_norm_ED  : 1.00
# Best_accuracy    : 98.677, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7                         | 7                         | 0.9926	True
# 109                       | 109                       | 0.5647	True
# 34                        | 34                        | 0.9912	True
# 289                       | 289                       | 0.9835	True
# 109                       | 109                       | 0.9654	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [2200/5000] Train loss: 0.06047, Valid loss: 0.02057, Elapsed_time: 2184.20082, current_LR: 0.0000063
# Current_accuracy : 98.842, Current_norm_ED  : 1.00
# Best_accuracy    : 98.842, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 72                        | 72                        | 0.9955	True
# 46                        | 46                        | 0.9934	True
# 85                        | 85                        | 0.9895	True
# 32                        | 32                        | 0.9951	True
# 179                       | 179                       | 0.9544	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [2400/5000] Train loss: 0.05756, Valid loss: 0.01999, Elapsed_time: 2380.33377, current_LR: 0.0000058
# Current_accuracy : 98.842, Current_norm_ED  : 1.00
# Best_accuracy    : 98.842, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 23                        | 23                        | 0.9914	True
# 109                       | 109                       | 0.9930	True
# 23                        | 23                        | 0.9863	True
# 76                        | 76                        | 0.9955	True
# 599                       | 599                       | 0.3336	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [2600/5000] Train loss: 0.05670, Valid loss: 0.02040, Elapsed_time: 2574.51689, current_LR: 0.0000052
# Current_accuracy : 98.842, Current_norm_ED  : 1.00
# Best_accuracy    : 98.842, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 847                       | 847                       | 0.9810	True
# 89                        | 89                        | 0.9897	True
# 86                        | 86                        | 0.9839	True
# 189                       | 189                       | 0.9859	True
# 279                       | 279                       | 0.9757	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [2800/5000] Train loss: 0.05395, Valid loss: 0.01831, Elapsed_time: 2771.12500, current_LR: 0.0000047
# Current_accuracy : 98.953, Current_norm_ED  : 1.00
# Best_accuracy    : 98.953, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 89                        | 89                        | 0.9965	True
# 97                        | 97                        | 0.9944	True
# 9350                      | 9350                      | 0.9802	True
# 47                        | 47                        | 0.9983	True
# 47                        | 47                        | 0.9910	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [3000/5000] Train loss: 0.05482, Valid loss: 0.01961, Elapsed_time: 2973.15191, current_LR: 0.0000041
# Current_accuracy : 98.897, Current_norm_ED  : 1.00
# Best_accuracy    : 98.953, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 109                       | 109                       | 0.9883	True
# 42                        | 42                        | 0.9978	True
# 34                        | 34                        | 0.9950	True
# 36                        | 36                        | 0.9929	True
# 96                        | 96                        | 0.9955	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [3200/5000] Train loss: 0.05049, Valid loss: 0.01959, Elapsed_time: 3168.24343, current_LR: 0.0000036
# Current_accuracy : 98.953, Current_norm_ED  : 1.00
# Best_accuracy    : 98.953, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 159                       | 159                       | 0.9060	True
# 159                       | 159                       | 0.9798	True
# 199                       | 199                       | 0.9515	True
# 96                        | 96                        | 0.9789	True
# 199                       | 199                       | 0.9840	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [3400/5000] Train loss: 0.05106, Valid loss: 0.01940, Elapsed_time: 3362.91248, current_LR: 0.0000031
# Current_accuracy : 98.953, Current_norm_ED  : 1.00
# Best_accuracy    : 98.953, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 26                        | 26                        | 0.9981	True
# 34                        | 34                        | 0.9931	True
# 5279                      | 5279                      | 0.8832	True
# 189                       | 189                       | 0.5369	True
# 72                        | 72                        | 0.9944	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [3600/5000] Train loss: 0.04978, Valid loss: 0.01975, Elapsed_time: 3557.49180, current_LR: 0.0000026
# Current_accuracy : 98.842, Current_norm_ED  : 1.00
# Best_accuracy    : 98.953, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 189                       | 189                       | 0.6215	True
# 389                       | 389                       | 0.8335	True
# 72                        | 72                        | 0.9961	True
# 139                       | 139                       | 0.7883	True
# 32                        | 32                        | 0.9895	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [3800/5000] Train loss: 0.04921, Valid loss: 0.02151, Elapsed_time: 3752.57941, current_LR: 0.0000022
# Current_accuracy : 98.953, Current_norm_ED  : 1.00
# Best_accuracy    : 98.953, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 49                        | 9                         | 0.9481	False
# 159                       | 159                       | 0.9920	True
# 96                        | 96                        | 0.9936	True
# 92                        | 92                        | 0.9938	True
# 83                        | 83                        | 0.9945	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [4000/5000] Train loss: 0.04411, Valid loss: 0.01926, Elapsed_time: 3947.26529, current_LR: 0.0000019
# Current_accuracy : 99.063, Current_norm_ED  : 1.00
# Best_accuracy    : 99.063, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 199                       | 199                       | 0.9871	True
# 109                       | 109                       | 0.9829	True
# 69                        | 69                        | 0.9970	True
# 32                        | 32                        | 0.9873	True
# 129                       | 129                       | 0.9936	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [4200/5000] Train loss: 0.04654, Valid loss: 0.01995, Elapsed_time: 4143.35989, current_LR: 0.0000016
# Current_accuracy : 98.953, Current_norm_ED  : 1.00
# Best_accuracy    : 99.063, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 86                        | 86                        | 0.9918	True
# 32                        | 32                        | 0.9942	True
# 109                       | 109                       | 0.9873	True
# 35                        | 35                        | 0.9914	True
# 129                       | 129                       | 0.9950	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [4400/5000] Train loss: 0.04925, Valid loss: 0.01946, Elapsed_time: 4337.98793, current_LR: 0.0000013
# Current_accuracy : 98.842, Current_norm_ED  : 1.00
# Best_accuracy    : 99.063, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 26                        | 26                        | 0.9970	True
# 167                       | 167                       | 0.9676	True
# 169                       | 169                       | 0.9928	True
# 11                        | 11                        | 0.9775	True
# 199                       | 199                       | 0.9272	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [4600/5000] Train loss: 0.04550, Valid loss: 0.01985, Elapsed_time: 4533.79749, current_LR: 0.0000011
# Current_accuracy : 98.787, Current_norm_ED  : 1.00
# Best_accuracy    : 99.063, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 72                        | 72                        | 0.9938	True
# 209                       | 209                       | 0.8283	True
# 159                       | 159                       | 0.9266	True
# 89                        | 89                        | 0.9784	True
# 79                        | 79                        | 0.9956	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [4800/5000] Train loss: 0.04204, Valid loss: 0.02189, Elapsed_time: 4728.34912, current_LR: 0.0000010
# Current_accuracy : 98.677, Current_norm_ED  : 1.00
# Best_accuracy    : 99.063, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 321                       | 321                       | 0.8162	True
# 69                        | 69                        | 0.9992	True
# 37                        | 37                        | 0.9815	True
# 129                       | 129                       | 0.9925	True
# 139                       | 139                       | 0.9843	True
# --------------------------------------------------------------------------------
# Train model:   0% 0/200 [00:00<?, ?it/s]
#
# [5000/5000] Train loss: 0.05198, Valid loss: 0.01955, Elapsed_time: 4923.62946, current_LR: 0.0000010
# Current_accuracy : 98.787, Current_norm_ED  : 1.00
# Best_accuracy    : 99.063, Best_norm_ED     : 1.00
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 139                       | 139                       | 0.9864	True
# 76                        | 76                        | 0.9981	True
# 139                       | 139                       | 0.8541	True
# 29609                     | 29609                     | 0.4736	True
# 287                       | 287                       | 0.9736	True
# --------------------------------------------------------------------------------
# end the training
# Train model:   0% 0/200 [00:12<?, ?it/s]
